# %%
import keras

# %%
parent_folder = 'all_data_splits'
train_data_dir = f'{parent_folder}/train'
test_data_dir = f'{parent_folder}/test'
val_data_dir = f'{parent_folder}/val'

# %%
model_path = 'all_model/model_rmsprop.h5'

# %%
model = keras.models.load_model(model_path)
# Out:
# 2022-09-04 10:58:00.352333: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-04 10:58:00.352413: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ankan): /proc/driver/nvidia/version does not exist
# 2022-09-04 10:58:00.371810: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = keras.models.load_model(model_path)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 1024)              25691136
#
#  dense_5 (Dense)             (None, 12)                12300
#
# ...
# Total params: 40,418,124
# Trainable params: 25,703,436
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from PIL import Image
import numpy as np
from skimage import transform

# %%
class_idx = {'Apple_Bad': 0,
 'Apple_Good': 1,
 'Banana_Bad': 2,
 'Banana_Good': 3,
 'Guava_Bad': 4,
 'Guava_Good': 5,
 'Lime_Bad': 6,
 'Lime_Good': 7,
 'Orange_Bad': 8,
 'Orange_Good': 9,
 'Pomegranate_Bad': 10,
 'Pomegranate_Good': 11}

# %%
data_folder = 'all_data'

# %%
def load(filename: str, w: int or float, h: int or float, ch: int or float) -> np.ndarray:
   np_image = Image.open(filename)
   np_image = np.array(np_image).astype('float32')
   np_image = transform.resize(np_image, (w, h, ch))
   np_image = np.expand_dims(np_image, axis=0)
   return np_image

# %%
from pathlib import Path

# %%
hit = 0
miss = 0
p = Path(test_data_dir)
for label in p.iterdir():
    plabel = Path(label)
    fruit_idx = class_idx[label.name]
    print(f'NAME: {label.name}, IDX: {fruit_idx}')
    for sample in plabel.iterdir():
        image = load(sample, 224, 224, 3)
        if fruit_idx == np.argmax(model.predict(image)):
            hit = hit + 1
        else:
            miss = miss + 1
# Out:
# NAME: Lime_Bad, IDX: 6
# ...
# 1/1 [==============================] - 0s 251ms/step
# NAME: Lime_Good, IDX: 7
# ...
# 1/1 [==============================] - 0s 248ms/step
# NAME: Apple_Bad, IDX: 0
# ...
# 1/1 [==============================] - 0s 251ms/step
# NAME: Pomegranate_Bad, IDX: 10
# ...
# 1/1 [==============================] - 0s 250ms/step
# NAME: Banana_Bad, IDX: 2
# ...
# 1/1 [==============================] - 0s 250ms/step
# ...
# ...
# 1/1 [==============================] - 0s 248ms/step
# NAME: Orange_Bad, IDX: 8
# ...
# 1/1 [==============================] - 0s 248ms/step

# %%
hit
# Out:
# 3431

# %%
miss
# Out:
# 259

# %%
miss/(hit+miss)
# Out:
# 0.07018970189701897

# %%
hit/(hit+miss)
# Out:
# 0.929810298102981

# %%
hitall = 0
missall = 0
p = Path('all_data')
for label in p.iterdir():
    plabel = Path(label)
    fruit_idx = class_idx[label.name]
    print(f'NAME: {label.name}, IDX: {fruit_idx}')
    for sample in plabel.iterdir():
        image = load(sample, 224, 224, 3)
        if fruit_idx == np.argmax(model.predict(image)):
            hitall = hitall + 1
        else:
            missall = missall + 1
# Out:
# NAME: Lime_Bad, IDX: 6
# ...
# 1/1 [==============================] - 0s 259ms/step
# ...
# ...
# 1/1 [==============================] - 0s 249ms/step

# %%
hitall
# Out:
# 17304

# %%
missall
# Out:
# 1148

# %%
tot=hitall+missall

# %%
hitall/tot
# Out:
# 0.9377845220030349

# %%
missall/tot
# Out:
# 0.0622154779969651
